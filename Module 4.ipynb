# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

df = pd.read_csv('df_arabica_clean.csv')
df.head()
# Out:
#    Unnamed: 0  ID Country of Origin                 Farm Name  \
# 0           0   0          Colombia          Finca El Paraiso
# 1           1   1            Taiwan  Royal Bean Geisha Estate
# 2           2   2              Laos        OKLAO coffee farms
# 3           3   3        Costa Rica                 La Cumbre
# 4           4   4          Colombia           Finca Santuario
#
#                                 Lot Number                           Mill  \
# 0                               CQU2022015               Finca El Paraiso
# 1  The 2022 Pacific Rim Coffee Summit,T037       Royal Bean Geisha Estate
# 2  The 2022 Pacific Rim Coffee Summit,LA01  oklao coffee processing plant
# 3                               CQU2022017        La Montana Tarrazu MIll
# 4                               CQU2023002                Finca Santuario
#
#   ICO Number                   Company   Altitude                Region  ...  \
# ...

# %%
# select features
features = ['Aroma', 'Flavor', 'Aftertaste', 'Acidity', 'Body', 'Balance', 'Uniformity', 'Overall', 'Total Cup Points']

# drop empty cells
X = df[features]

# scale data for use
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# setup for finding K-Means
inertia = []
k_values = range(2, 11)

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)
    
# plot graph
plt.plot(k_values, inertia, marker='o')
plt.title('K-Means Inertia')
plt.xlabel("Number of clusters")
plt.ylabel("Inertia Values")
plt.grid(True)
plt.show()
# Out:
# C:\Users\brand\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\brand\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\brand\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
# fit kmeans with k=4 from elbow graph above
kmeans = KMeans(n_clusters=4, random_state=42, n_init=10)
clusters = kmeans.fit_predict(X_scaled)

# columns to compare in scatterplot
aroma = X_scaled[:, 0]
flavor = X_scaled[:, 1]
aftertaste = X_scaled[:, 2]
acidity = X_scaled[:, 3]
body = X_scaled[:, 4]
balance = X_scaled[:, 5]
uniformity = X_scaled[:, 6]
overall = X_scaled[:, 7]
total_points = X_scaled[:, 8]


# plot with scatterplot
plt.scatter(overall, total_points, c=clusters, cmap='viridis', s=50)
plt.title('Overall Rating vs. Total Cup Points')
plt.colorbar(label='Cluster')
plt.grid(True)
plt.show()
# Out:
# C:\Users\brand\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
df['Cluster'] = kmeans.fit_predict(X_scaled)
cluster_means = df.groupby('Cluster')[features].mean().round(2)
cluster_means
# Out:
# C:\Users\brand\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
#          Aroma  Flavor  Aftertaste  Acidity  Body  Balance  Uniformity  \
# Cluster
# 0         7.66    7.70        7.54     7.65  7.63     7.61        10.0
# 1         7.99    8.01        7.86     7.92  7.83     7.88        10.0
# 2         7.38    7.36        7.25     7.35  7.32     7.29        10.0
# 3         7.84    7.84        7.67     7.84  7.75     7.92         9.0
#
#          Overall  Total Cup Points
# Cluster
# 0           7.60             83.38
# 1           7.98             85.47
# 2           7.28             81.23
# 3           7.92             83.75
